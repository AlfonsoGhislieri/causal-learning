# %% [markdown]
# # Pre-processing data set

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('world-happiness-report-2021.csv')

# %% [markdown]
# ## Feature selection
# Drop irrelevant features

# %%
# drop columns
df = df.drop([
  'Country name', 'Standard error of ladder score', 'upperwhisker','lowerwhisker',
  'Ladder score in Dystopia', 'Dystopia + residual', 'Logged GDP per capita',
  'Social support', 'Healthy life expectancy', 'Freedom to make life choices',
  'Generosity', 'Perceptions of corruption', 'Regional indicator'
   ], axis=1)

# %%
df
# Out:
#      Ladder score  Explained by: Log GDP per capita  \
# 0           7.842                             1.446
# 1           7.620                             1.502
# 2           7.571                             1.566
# 3           7.554                             1.482
# 4           7.464                             1.501
# ..            ...                               ...
# 144         3.512                             0.451
# 145         3.467                             1.099
# 146         3.415                             0.364
# 147         3.145                             0.457
# 148         2.523                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption
# 0                                      0.481
# 1                                      0.485
# 2                                      0.413
# 3                                      0.170
# 4                                      0.384
# ..                                       ...
# 144                                    0.015
# 145                                    0.088
# 146                                    0.493
# 147                                    0.075
# 148                                    0.010
#
# [149 rows x 7 columns]

# %%
# check data types
df.dtypes
# Out:
# Ladder score                                  float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# dtype: object

# %%
df.describe()
# Out:
#        Ladder score  Explained by: Log GDP per capita  \
# count    149.000000                        149.000000
# mean       5.532839                          0.977161
# std        1.073924                          0.404740
# min        2.523000                          0.000000
# 25%        4.852000                          0.666000
# 50%        5.534000                          1.025000
# 75%        6.255000                          1.323000
# max        7.842000                          1.751000
#
#        Explained by: Social support  Explained by: Healthy life expectancy  \
# count                    149.000000                             149.000000
# mean                       0.793315                               0.520161
# std                        0.258871                               0.213019
# min                        0.000000                               0.000000
# 25%                        0.647000                               0.357000
# 50%                        0.832000                               0.571000
# 75%                        0.996000                               0.665000
# max                        1.172000                               0.897000
#
#        Explained by: Freedom to make life choices  Explained by: Generosity  \
# count                                  149.000000                149.000000
# mean                                     0.498711                  0.178047
# std                                      0.137888                  0.098270
# min                                      0.000000                  0.000000
# 25%                                      0.409000                  0.105000
# 50%                                      0.514000                  0.164000
# 75%                                      0.603000                  0.239000
# max                                      0.716000                  0.541000
#
#        Explained by: Perceptions of corruption
# count                               149.000000
# mean                                  0.135141
# std                                   0.114361
# min                                   0.000000
# 25%                                   0.060000
# 50%                                   0.101000
# 75%                                   0.174000
# max                                   0.547000

# %%
# Convert numeric explained by data into categorical

# define the range of values 
bins = np.arange(0, 1.9, 0.1)

# use pd.cut() to map the numerical values to the categorical values
for col in df.columns:
    if col not in ['Regional indicator', 'Ladder score']:
        df[col] = pd.cut(df[col], bins=bins, include_lowest=True)

# %%
# Convert ladder score data into categorical

# define the range of values 
bins = np.arange(0, 8.5, 0.5)

# use pd.cut() to map the numerical values to the categorical values
for col in df.columns:
    if col == 'Ladder score':
        df[col] = pd.cut(df[col], bins=bins, include_lowest=True)

# %%
df.dtypes
# Out:
# Ladder score                                  category
# Explained by: Log GDP per capita              category
# Explained by: Social support                  category
# Explained by: Healthy life expectancy         category
# Explained by: Freedom to make life choices    category
# Explained by: Generosity                      category
# Explained by: Perceptions of corruption       category
# dtype: object

# %%
df
# Out:
#     Ladder score Explained by: Log GDP per capita  \
# 0     (7.5, 8.0]                       (1.4, 1.5]
# 1     (7.5, 8.0]                       (1.5, 1.6]
# 2     (7.5, 8.0]                       (1.5, 1.6]
# 3     (7.5, 8.0]                       (1.4, 1.5]
# 4     (7.0, 7.5]                       (1.5, 1.6]
# ..           ...                              ...
# 144   (3.5, 4.0]                       (0.4, 0.5]
# 145   (3.0, 3.5]                       (1.0, 1.1]
# 146   (3.0, 3.5]                       (0.3, 0.4]
# 147   (3.0, 3.5]                       (0.4, 0.5]
# 148   (2.5, 3.0]                       (0.3, 0.4]
#
#     Explained by: Social support Explained by: Healthy life expectancy  \
# 0                     (1.1, 1.2]                            (0.7, 0.8]
# 1                     (1.1, 1.2]                            (0.7, 0.8]
# 2                     (1.0, 1.1]                            (0.8, 0.9]
# 3                     (1.1, 1.2]                            (0.7, 0.8]
# 4                     (1.0, 1.1]                            (0.7, 0.8]
# ..                           ...                                   ...
# 144                   (0.7, 0.8]                         (-0.001, 0.1]
# 145                   (0.7, 0.8]                            (0.3, 0.4]
# 146                   (0.2, 0.3]                            (0.4, 0.5]
# 147                   (0.6, 0.7]                            (0.2, 0.3]
# 148                (-0.001, 0.1]                            (0.1, 0.2]
#
#     Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                   (0.6, 0.7]               (0.1, 0.2]
# 1                                   (0.6, 0.7]               (0.2, 0.3]
# 2                                   (0.6, 0.7]               (0.2, 0.3]
# 3                                   (0.6, 0.7]               (0.2, 0.3]
# 4                                   (0.6, 0.7]               (0.3, 0.4]
# ..                                         ...                      ...
# 144                                 (0.4, 0.5]               (0.1, 0.2]
# 145                                 (0.5, 0.6]            (-0.001, 0.1]
# 146                                 (0.6, 0.7]               (0.2, 0.3]
# 147                                 (0.3, 0.4]               (0.1, 0.2]
# 148                              (-0.001, 0.1]               (0.1, 0.2]
#
#     Explained by: Perceptions of corruption
# 0                                (0.4, 0.5]
# 1                                (0.4, 0.5]
# 2                                (0.4, 0.5]
# 3                                (0.1, 0.2]
# 4                                (0.3, 0.4]
# ..                                      ...
# 144                           (-0.001, 0.1]
# 145                           (-0.001, 0.1]
# 146                              (0.4, 0.5]
# 147                           (-0.001, 0.1]
# 148                           (-0.001, 0.1]
#
# [149 rows x 7 columns]

# %%
# check for null values
df.isna().sum()
# Out:
# Ladder score                                  0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64
